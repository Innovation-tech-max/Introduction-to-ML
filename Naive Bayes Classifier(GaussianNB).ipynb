# %% [markdown]
# # Gaussian Naive Bayes

# %%
import pandas as pd
import sklearn
import seaborn
import numpy as np
import matplotlib

# %% [markdown]
# ## Load the data

# %%
iris_data=pd.read_csv("Iris.csv")
iris_data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # VISUALISATION

# %%
iris_data.plot(kind='box', subplots=True, layout=(2,3), sharex=False, sharey=False)
plt.show()

# %%
seaborn.pairplot(iris_data, hue="Species", size=3, diag_kind="kde")
plt.show()
# Out:
# /home/mukut/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
seaborn.pairplot(iris_data, hue="Species", size = 3)
seaborn.set()
# Out:
# /home/mukut/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris_data.hist()
plt.show()

# %%
#seperate feature and target variable
X=iris_data.drop(['Id','Species'],axis=1)
y=iris_data['Species']

# %% [markdown]
# ## Create Train and Test dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=56)

# %%
X_train.shape
# Out:
# (105, 4)

# %%
y_train.shape
# Out:
# (105,)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 84             5.4           3.0            4.5           1.5
# 126            6.2           2.8            4.8           1.8
# 109            7.2           3.6            6.1           2.5
# 99             5.7           2.8            4.1           1.3
# 36             5.5           3.5            1.3           0.2
# ..             ...           ...            ...           ...
# 87             6.3           2.3            4.4           1.3
# 142            5.8           2.7            5.1           1.9
# 122            7.7           2.8            6.7           2.0
# 143            6.8           3.2            5.9           2.3
# 85             6.0           3.4            4.5           1.6
#
# [105 rows x 4 columns]

# %%
y_test
# Out:
# 137     Iris-virginica
# 98     Iris-versicolor
# 77     Iris-versicolor
# 141     Iris-virginica
# 120     Iris-virginica
# 145     Iris-virginica
# 146     Iris-virginica
# 35         Iris-setosa
# 12         Iris-setosa
# 127     Iris-virginica
# 71     Iris-versicolor
# 4          Iris-setosa
# 0          Iris-setosa
# 18         Iris-setosa
# 83     Iris-versicolor
# 6          Iris-setosa
# 7          Iris-setosa
# 9          Iris-setosa
# 103     Iris-virginica
# 81     Iris-versicolor
# 42         Iris-setosa
# 108     Iris-virginica
# 57     Iris-versicolor
# 68     Iris-versicolor
# 30         Iris-setosa
# 104     Iris-virginica
# 105     Iris-virginica
# 63     Iris-versicolor
# 73     Iris-versicolor
# 53     Iris-versicolor
# 112     Iris-virginica
# 101     Iris-virginica
# 72     Iris-versicolor
# 40         Iris-setosa
# 38         Iris-setosa
# 45         Iris-setosa
# 131     Iris-virginica
# 128     Iris-virginica
# 107     Iris-virginica
# 21         Iris-setosa
# ...

# %% [markdown]
# ## Implement Guassian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
naive_bayes=GaussianNB()

# %%
#train the model and make prediction
naive_bayes.fit(X_train,y_train)
predictions= naive_bayes.predict(X_test)

# %%
#calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predictions)
# Out:
# 0.9333333333333333

# %%
print("Prediction of Species: {}".format(predictions))
# Out:
# Prediction of Species: ['Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-versicolor']

# %%
X_new = np.array([[3, 2, 4, 0.2], [  4.7, 3, 1.3, 0.2 ]])
print("X_new.shape: {}".format(X_new.shape))
# Out:
# X_new.shape: (2, 4)

# %%
prediction = naive_bayes.predict(X_new)

# %%
#Prediction of the species from the input vector
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-versicolor' 'Iris-setosa']

# %% [markdown]
# # Thank you!
